# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass  \
# 268          269         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 268  Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 268      1  PC 17582  153.4625  C125        S

# %%
df['Sex'] # df[Column 이름] = update value --> 모든 값들이 update 됨
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
# del df[Column 이름] --> 삭제
